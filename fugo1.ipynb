# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_columns', None)
from datetime import datetime
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier,CatBoostRegressor

# %%
path = "C:/Users/HP/Desktop/fugo/"

os.listdir(path)

def get_datetime_from_timestamp(val):
    return datetime.fromtimestamp(val / 1000000)

# %%
targets_train = pd.read_csv(path + "targets_train.csv")
users_test = pd.read_csv(path + "users_test.csv")
users_train = pd.read_csv(path + "users_train.csv")
user_features_test = pd.read_csv(path + "user_features_test.csv")
user_features_train = pd.read_csv(path + "user_features_train.csv")

id_target_map = {i[0]:i[1] for i in targets_train.values}

# %%
df_train = pd.concat([user_features_train, users_train],axis=1)
df_test = pd.concat([user_features_test, users_test],axis=1)

# %%
df_train["target"] =  df_train["ID"].iloc[:,0].map(id_target_map)

stat_df = pd.DataFrame(columns=["iter","fold","train_score","test_score"])

# %%
df_train["date"] = df_train["first_open_timestamp"].apply(get_datetime_from_timestamp)
df_test["date"] = df_test["first_open_timestamp"].apply(get_datetime_from_timestamp)

df_train["local_date"] = df_train["local_first_open_timestamp"].apply(get_datetime_from_timestamp)
df_test["local_date"] = df_test["local_first_open_timestamp"].apply(get_datetime_from_timestamp)

# %%
exc_cols = ["first_open_date","ID", "date", "local_date", "fold", "target", "grp"]
cat_cols = [i for i in users_train.columns if users_train[i].dtype == "O" and i not in exc_cols]

ret_cols = [i for i in user_features_train.columns if "retention" in i.lower()]
level_advanced_cols = [i for i in user_features_train.columns if "leveladvanced" in i.lower()]
level_duration_cols = [i for i in user_features_train.columns if "level" in i.lower() and "duration" in i.lower()]
ad_revenue_cols = [i for i in user_features_train.columns if "adrevenue" in i.lower() ]
ap_revenue_cols = [i for i in user_features_train.columns if "aprevenue" in i.lower() ]

# %%
def get_cat_mean_feature(train_df, test_df):

    for col in cat_cols:
        mean_encoding_map = {i[0]:i[1] for i in  train_df.groupby(col)["target"].mean().reset_index().values}
        train_df[col + "_mean_encoding"] = train_df[col].map(mean_encoding_map)
        test_df[col + "_mean_encoding"] = test_df[col].map(mean_encoding_map)

    if "target" in list(train_df.columns):
        train_df = train_df.drop("target", axis=1)

        
    return train_df, test_df

# %%
fold_count = 5
# base_kf = KFold(n_splits=fold_count, shuffle=True, random_state=42)

def get_general_stats(df, cols, pref_name):
    sum_ = df[cols].sum(axis=1)
    std_ = df[cols].std(axis=1)
    
    cummax_df = df[cols].cummax(axis=1)
    cummax_df.columns = [i + "_cummax" for i in cummax_df]

    cummin_df = df[cols].cummin(axis=1)
    cummin_df.columns = [i + "_cummin" for i in cummin_df]

    cumsum_df = df[cols].cumsum(axis=1)
    cumsum_df.columns = [i + "_cumsum" for i in cumsum_df]
    
    fin_df = pd.concat([cummax_df,cummin_df, cumsum_df],axis=1)

    fin_df[pref_name + "_sum"] = sum_
    fin_df[pref_name + "_std"] = std_
    
    return fin_df

def get_retention_stats(df):
    mean_retentions = df[ret_cols].mean(axis=1)
    std_retentions = df[ret_cols].std(axis=1)
    
    cumsum_df = df[ret_cols].cumsum(axis=1)
    cumsum_df.columns = [i + "cumsum" for i in ret_cols]

    cumsum_df["mean_retentions"] = mean_retentions
    cumsum_df["std_retentions"] = std_retentions
    
    return cumsum_df

def get_time_related_feats(df):
    date_ = df["first_open_timestamp"].apply(get_datetime_from_timestamp)
    local_date = df["local_first_open_timestamp"].apply(get_datetime_from_timestamp)

    def get_datetime_feats(col):
        month = date_.dt.month
        year = date_.dt.year
        day = date_.dt.day
        hour = date_.dt.hour
        return month, year, day, hour
    

    day_diff = (date_ - local_date).dt.days
    second_diff = (date_ - local_date).dt.seconds
    hour_diff = second_diff //  3600
    df_ = pd.concat([day_diff, hour_diff],axis=1)
    df_.columns = ["day_diff", "hour_diff"]

    df_["month"], df_["year"], df_["day"], df_["hour"] = get_datetime_feats(date_)
    df_["local_month"], df_["local_myear"], df_["local_mday"], df_["local_mhour"] = get_datetime_feats(local_date)
    return df_

def get_score(y, y_pred):   
    mse = np.mean((y - y_pred)**2)
    return mse ** (1/2)

# %%
import numpy as np

def SumOfAverageFunction(vals):
    return (abs(np.divide(df2.values, df1.loc[vals.index].values)-1)*100).sum()

# vals = df1.column1.rolling(3)
# vals.apply(SumOfAverageFunction, raw=False)

# %%
a = df_train[ad_revenue_cols].head(100)

# %%
def get_div_vals(df,col_names):
    a = df[col_names]
    b = a.T.values
    liste = []
    for i in range(1,a.shape[1]):
        liste.append(b[i]/ b[i-1])

    dff = pd.DataFrame(liste).T
    dff.columns = [i + "_div_col" for i in col_names[:-1]]
    dff.index = df.index
    return dff

# %%
def get_rolling_stats(df, rol_cols, rol_step, rol_aggs = ["mean"]):
    df_list = []
    if "mean" in rol_aggs:
        df[rol_cols] = df[rol_cols]*1
        rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
        rol_df_mean = rol_df_mean.iloc[:,1:]
        rol_df_mean.columns = [i + f"_rolling_{rol_step}_mean" for i in rol_df_mean.columns]
        df_list.append(rol_df_mean)
    if "max" in rol_aggs:
        df[rol_cols] = df[rol_cols]*1
        rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
        rol_df_max = rol_df_max.iloc[:,1:]
        rol_df_max.columns = [i + f"_rolling_{rol_step}_max" for i in rol_df_max.columns]
        df_list.append(rol_df_max)

    fin = pd.concat(df_list,axis=1)
    return fin



def count_zeros(df, cols, cols_name):
    a = (df[cols] == 0).sum(axis=1)
    b = (df[cols] != 0).sum(axis=1)
    return a , b

# %%
col_couples = [("advanced", level_advanced_cols), ("duration",level_duration_cols), ("ad_revenue",ad_revenue_cols), ("ap_revenue",ap_revenue_cols)]

def make_main_df(train_or_test):
    generated_feats = []

    if train_or_test == "train":
        df = df_train.copy().iloc[:100]
    else:
        df = df_test.copy().iloc[:100]

    print("--------train_or_test ------------")
    generated_feats.append(get_retention_stats(df))
    generated_feats.append(get_time_related_feats(df))


    for col_name, col in col_couples:
        gen_stat_df = get_general_stats(df, col, col_name)
        generated_feats.append(gen_stat_df)
        for rol_step in [2,3,4,5]:
            generated_feats.append(get_rolling_stats(df, col, rol_step, rol_aggs = ["mean","max"]))
    print("---------  1   -----------------")
    for rol_step in [2,3,4,5]:
        generated_feats.append(get_rolling_stats(df, ret_cols, rol_step, rol_aggs = ["mean"]))
    print("---------  2   -----------------")

    # fin_df = pd.concat(generated_feats, axis=1)

    for col_name, col in col_couples:
        generated_feats.append(get_div_vals(df,col))
    print("---------  3   -----------------")

    first = generated_feats[0]
    for i in generated_feats[1:]:
        first = first.join(i)
    print("---------  4   -----------------")

    fin_df = pd.concat([df,first ],axis=1)
    print("---------  5   -----------------")

    for col_name, col in col_couples:
        fin_df[f"{col_name}_zero_count"], fin_df[f"{col_name}_nonzero_count"]  =  count_zeros(df, col, col_name)
        print("---------  5   -----------------")

    return fin_df
    # return fin_df, generated_feats

# %%
merged_train = make_main_df("train")
merged_test = make_main_df("test")
# Out:
# --------train_or_test ------------
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: invalid value encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: divide by zero encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: divide by zero encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: invalid value encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: invalid value encountered in divide
#   liste.append(b[i]/ b[i-1])
# ---------  1   -----------------
# ---------  2   -----------------
# ---------  3   -----------------
# ---------  4   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# --------train_or_test ------------
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# ---------  1   -----------------
# ---------  2   -----------------
# ---------  3   -----------------
# ---------  4   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# ---------  5   -----------------
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:11: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_max = df[rol_cols].rolling(rol_step,axis=1).max()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\2113355818.py:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
#   rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: invalid value encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: divide by zero encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: divide by zero encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: invalid value encountered in divide
#   liste.append(b[i]/ b[i-1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_3904\689276040.py:6: RuntimeWarning: invalid value encountered in divide
#   liste.append(b[i]/ b[i-1])

# %%
merged_train[cat_cols] = merged_train[cat_cols].fillna("nan")
merged_test[cat_cols] = merged_test[cat_cols].fillna("nan")

# %%
asd = """<ipython-input-35-6d45861fb45e>:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
  rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
<ipython-input-35-6d45861fb45e>:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
  rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
<ipython-input-35-6d45861fb45e>:5: FutureWarning: Support for axis=1 in DataFrame.rolling is deprecated and will be removed in a future version. Use obj.T.rolling(...) instead
  rol_df_mean = df[rol_cols].rolling(rol_step,axis=1).mean()
""".split("rol_df_mean")

# %%
len(asd)
# Out:
# 4

# %%
fold_count = 5
def create_folds(dff, n_s=5, n_grp=None):
    df = dff.copy()
    df['fold'] = -1
    
    if n_grp is None:
        skf = KFold(n_splits=n_s, random_state=42,  shuffle=True)
        target = df.target
    else:
        skf = StratifiedKFold(n_splits=n_s, random_state=42, shuffle=True)
        df['grp'] = pd.cut(df.target, n_grp, labels=False)
        target = df.grp
    
    for fold_no, (t, v) in enumerate(skf.split(target, target)):
        df.loc[v, 'fold'] = fold_no
    return df

df_to_train = create_folds(merged_train, n_s=fold_count, n_grp=fold_count)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
train_cols = [i for i in df_to_train.columns if i not in exc_cols]
len(train_cols)
# Out:
# 848

# %%
for iter in [50]:
  for fold in range(fold_count):

    X_train = df_to_train.loc[df_to_train.fold != fold][train_cols] 
    X_test = df_to_train.loc[df_to_train.fold == fold][train_cols] 
    y_train = df_to_train.loc[df_to_train.fold != fold]["target"] 
    y_test = df_to_train.loc[df_to_train.fold == fold]["target"] 

    X_train, X_test = get_cat_mean_feature(df_to_train.loc[df_to_train.fold != fold][train_cols + ["target"]] ,
                                            df_to_train.loc[df_to_train.fold == fold][train_cols + ["target"]] )

    model=CatBoostRegressor(verbose=0, iterations=iter, cat_features=cat_cols)##cat_features=cat_cols

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    test_score = get_score(y_test, y_pred)
    train_score = get_score(y_train, y_pred_train)
    print("fold :",fold, "test score :", test_score, "train_score :", train_score)
    row = {"iter":iter, "fold":fold, "train_score":train_score, "test_score":test_score}
    stat_df.loc[stat_df.shape[0]] = row
    break
# Out:
# fold : 0 test score : 0.100547060441087 train_score : 0.009111960686425401

# %%
train_cols
# Out:
# ['first_prediction',
#  'RetentionD0',
#  'RetentionD1',
#  'RetentionD2',
#  'RetentionD3',
#  'RetentionD4',
#  'RetentionD5',
#  'RetentionD6',
#  'RetentionD7',
#  'RetentionD8',
#  'RetentionD9',
#  'RetentionD10',
#  'RetentionD11',
#  'RetentionD12',
#  'RetentionD13',
#  'RetentionD14',
#  'RetentionD15',
#  'LevelAdvancedCountD0',
#  'LevelAdvancedCountD1',
#  'LevelAdvancedCountD2',
#  'LevelAdvancedCountD3',
#  'LevelAdvancedCountD4',
#  'LevelAdvancedCountD5',
#  'LevelAdvancedCountD6',
#  'LevelAdvancedCountD7',
#  'LevelAdvancedCountD8',
#  'LevelAdvancedCountD9',
#  'LevelAdvancedCountD10',
#  'LevelAdvancedCountD11',
#  'LevelAdvancedCountD12',
#  'LevelAdvancedCountD13',
#  'LevelAdvancedCountD14',
#  'LevelAdvancedCountD15',
#  'Level_1_Duration',
#  'Level_2_Duration',
#  'Level_3_Duration',
#  'Level_4_Duration',
#  'Level_5_Duration',
#  'Level_6_Duration',
#  'Level_7_Duration',
#  'Level_8_Duration',
#  'Level_9_Duration',
#  'Level_10_Duration',
#  'AdRevenueD0',
#  'AdRevenueD1',
#  'AdRevenueD2',
#  'AdRevenueD3',
#  'AdRevenueD4',
#  'AdRevenueD5',
#  'AdRevenueD6',
#  'AdRevenueD7',
#  'AdRevenueD8',
#  'AdRevenueD9',
#  'AdRevenueD10',
#  'AdRevenueD11',
#  'AdRevenueD12',
#  'AdRevenueD13',
#  'AdRevenueD14',
#  'AdRevenueD15',
#  'IAPRevenueD0',
#  'IAPRevenueD1',
#  'IAPRevenueD2',
#  'IAPRevenueD3',
#  'IAPRevenueD4',
#  'IAPRevenueD5',
#  'IAPRevenueD6',
#  'IAPRevenueD7',
#  'IAPRevenueD8',
#  'IAPRevenueD9',
#  'IAPRevenueD10',
#  'IAPRevenueD11',
#  'IAPRevenueD12',
#  'IAPRevenueD13',
#  'IAPRevenueD14',
#  'IAPRevenueD15',
#  'first_open_timestamp',
#  'local_first_open_timestamp',
#  'country',
#  'platform',
#  'device_category',
#  'device_brand',
#  'device_model',
#  'has_ios_att_permission',
#  'ad_network',
#  'RetentionD0cumsum',
#  'RetentionD1cumsum',
#  'RetentionD2cumsum',
#  'RetentionD3cumsum',
#  'RetentionD4cumsum',
#  'RetentionD5cumsum',
#  'RetentionD6cumsum',
#  'RetentionD7cumsum',
#  'RetentionD8cumsum',
#  'RetentionD9cumsum',
#  'RetentionD10cumsum',
#  'RetentionD11cumsum',
#  'RetentionD12cumsum',
#  'RetentionD13cumsum',
#  'RetentionD14cumsum',
#  'RetentionD15cumsum',
#  'mean_retentions',
#  'std_retentions',
#  'day_diff',
#  'hour_diff',
#  'month',
#  'year',
#  'day',
#  'hour',
#  'local_month',
#  'local_myear',
#  'local_mday',
#  'local_mhour',
#  'LevelAdvancedCountD0_cummax',
#  'LevelAdvancedCountD1_cummax',
#  'LevelAdvancedCountD2_cummax',
#  'LevelAdvancedCountD3_cummax',
#  'LevelAdvancedCountD4_cummax',
#  'LevelAdvancedCountD5_cummax',
#  'LevelAdvancedCountD6_cummax',
#  'LevelAdvancedCountD7_cummax',
#  'LevelAdvancedCountD8_cummax',
#  'LevelAdvancedCountD9_cummax',
#  'LevelAdvancedCountD10_cummax',
#  'LevelAdvancedCountD11_cummax',
#  'LevelAdvancedCountD12_cummax',
#  'LevelAdvancedCountD13_cummax',
#  'LevelAdvancedCountD14_cummax',
#  'LevelAdvancedCountD15_cummax',
#  'LevelAdvancedCountD0_cummin',
#  'LevelAdvancedCountD1_cummin',
#  'LevelAdvancedCountD2_cummin',
#  'LevelAdvancedCountD3_cummin',
#  'LevelAdvancedCountD4_cummin',
#  'LevelAdvancedCountD5_cummin',
#  'LevelAdvancedCountD6_cummin',
#  'LevelAdvancedCountD7_cummin',
#  'LevelAdvancedCountD8_cummin',
#  'LevelAdvancedCountD9_cummin',
#  'LevelAdvancedCountD10_cummin',
#  'LevelAdvancedCountD11_cummin',
#  'LevelAdvancedCountD12_cummin',
#  'LevelAdvancedCountD13_cummin',
#  'LevelAdvancedCountD14_cummin',
#  'LevelAdvancedCountD15_cummin',
#  'LevelAdvancedCountD0_cumsum',
#  'LevelAdvancedCountD1_cumsum',
#  'LevelAdvancedCountD2_cumsum',
#  'LevelAdvancedCountD3_cumsum',
#  'LevelAdvancedCountD4_cumsum',
#  'LevelAdvancedCountD5_cumsum',
#  'LevelAdvancedCountD6_cumsum',
#  'LevelAdvancedCountD7_cumsum',
#  'LevelAdvancedCountD8_cumsum',
#  'LevelAdvancedCountD9_cumsum',
#  'LevelAdvancedCountD10_cumsum',
#  'LevelAdvancedCountD11_cumsum',
#  'LevelAdvancedCountD12_cumsum',
#  'LevelAdvancedCountD13_cumsum',
#  'LevelAdvancedCountD14_cumsum',
#  'LevelAdvancedCountD15_cumsum',
#  'advanced_sum',
#  'advanced_std',
#  'LevelAdvancedCountD1_rolling_2_mean',
#  'LevelAdvancedCountD2_rolling_2_mean',
#  'LevelAdvancedCountD3_rolling_2_mean',
#  'LevelAdvancedCountD4_rolling_2_mean',
#  'LevelAdvancedCountD5_rolling_2_mean',
#  'LevelAdvancedCountD6_rolling_2_mean',
#  'LevelAdvancedCountD7_rolling_2_mean',
#  'LevelAdvancedCountD8_rolling_2_mean',
#  'LevelAdvancedCountD9_rolling_2_mean',
#  'LevelAdvancedCountD10_rolling_2_mean',
#  'LevelAdvancedCountD11_rolling_2_mean',
#  'LevelAdvancedCountD12_rolling_2_mean',
#  'LevelAdvancedCountD13_rolling_2_mean',
#  'LevelAdvancedCountD14_rolling_2_mean',
#  'LevelAdvancedCountD15_rolling_2_mean',
#  'LevelAdvancedCountD1_rolling_2_max',
#  'LevelAdvancedCountD2_rolling_2_max',
#  'LevelAdvancedCountD3_rolling_2_max',
#  'LevelAdvancedCountD4_rolling_2_max',
#  'LevelAdvancedCountD5_rolling_2_max',
#  'LevelAdvancedCountD6_rolling_2_max',
#  'LevelAdvancedCountD7_rolling_2_max',
#  'LevelAdvancedCountD8_rolling_2_max',
#  'LevelAdvancedCountD9_rolling_2_max',
#  'LevelAdvancedCountD10_rolling_2_max',
#  'LevelAdvancedCountD11_rolling_2_max',
#  'LevelAdvancedCountD12_rolling_2_max',
#  'LevelAdvancedCountD13_rolling_2_max',
#  'LevelAdvancedCountD14_rolling_2_max',
#  'LevelAdvancedCountD15_rolling_2_max',
#  'LevelAdvancedCountD1_rolling_3_mean',
#  'LevelAdvancedCountD2_rolling_3_mean',
#  'LevelAdvancedCountD3_rolling_3_mean',
#  'LevelAdvancedCountD4_rolling_3_mean',
#  'LevelAdvancedCountD5_rolling_3_mean',
#  'LevelAdvancedCountD6_rolling_3_mean',
#  'LevelAdvancedCountD7_rolling_3_mean',
#  'LevelAdvancedCountD8_rolling_3_mean',
#  'LevelAdvancedCountD9_rolling_3_mean',
#  'LevelAdvancedCountD10_rolling_3_mean',
#  'LevelAdvancedCountD11_rolling_3_mean',
#  'LevelAdvancedCountD12_rolling_3_mean',
#  'LevelAdvancedCountD13_rolling_3_mean',
#  'LevelAdvancedCountD14_rolling_3_mean',
#  'LevelAdvancedCountD15_rolling_3_mean',
#  'LevelAdvancedCountD1_rolling_3_max',
#  'LevelAdvancedCountD2_rolling_3_max',
#  'LevelAdvancedCountD3_rolling_3_max',
#  'LevelAdvancedCountD4_rolling_3_max',
#  'LevelAdvancedCountD5_rolling_3_max',
#  'LevelAdvancedCountD6_rolling_3_max',
#  'LevelAdvancedCountD7_rolling_3_max',
#  'LevelAdvancedCountD8_rolling_3_max',
#  'LevelAdvancedCountD9_rolling_3_max',
#  'LevelAdvancedCountD10_rolling_3_max',
#  'LevelAdvancedCountD11_rolling_3_max',
#  'LevelAdvancedCountD12_rolling_3_max',
#  'LevelAdvancedCountD13_rolling_3_max',
#  'LevelAdvancedCountD14_rolling_3_max',
#  'LevelAdvancedCountD15_rolling_3_max',
#  'LevelAdvancedCountD1_rolling_4_mean',
#  'LevelAdvancedCountD2_rolling_4_mean',
#  'LevelAdvancedCountD3_rolling_4_mean',
#  'LevelAdvancedCountD4_rolling_4_mean',
#  'LevelAdvancedCountD5_rolling_4_mean',
#  'LevelAdvancedCountD6_rolling_4_mean',
#  'LevelAdvancedCountD7_rolling_4_mean',
#  'LevelAdvancedCountD8_rolling_4_mean',
#  'LevelAdvancedCountD9_rolling_4_mean',
#  'LevelAdvancedCountD10_rolling_4_mean',
#  'LevelAdvancedCountD11_rolling_4_mean',
#  'LevelAdvancedCountD12_rolling_4_mean',
#  'LevelAdvancedCountD13_rolling_4_mean',
#  'LevelAdvancedCountD14_rolling_4_mean',
#  'LevelAdvancedCountD15_rolling_4_mean',
#  'LevelAdvancedCountD1_rolling_4_max',
#  'LevelAdvancedCountD2_rolling_4_max',
#  'LevelAdvancedCountD3_rolling_4_max',
#  'LevelAdvancedCountD4_rolling_4_max',
#  'LevelAdvancedCountD5_rolling_4_max',
#  'LevelAdvancedCountD6_rolling_4_max',
#  'LevelAdvancedCountD7_rolling_4_max',
#  'LevelAdvancedCountD8_rolling_4_max',
#  'LevelAdvancedCountD9_rolling_4_max',
#  'LevelAdvancedCountD10_rolling_4_max',
#  'LevelAdvancedCountD11_rolling_4_max',
#  'LevelAdvancedCountD12_rolling_4_max',
#  'LevelAdvancedCountD13_rolling_4_max',
#  'LevelAdvancedCountD14_rolling_4_max',
#  'LevelAdvancedCountD15_rolling_4_max',
#  'LevelAdvancedCountD1_rolling_5_mean',
#  'LevelAdvancedCountD2_rolling_5_mean',
#  'LevelAdvancedCountD3_rolling_5_mean',
#  'LevelAdvancedCountD4_rolling_5_mean',
#  'LevelAdvancedCountD5_rolling_5_mean',
#  'LevelAdvancedCountD6_rolling_5_mean',
#  'LevelAdvancedCountD7_rolling_5_mean',
#  'LevelAdvancedCountD8_rolling_5_mean',
#  'LevelAdvancedCountD9_rolling_5_mean',
#  'LevelAdvancedCountD10_rolling_5_mean',
#  'LevelAdvancedCountD11_rolling_5_mean',
#  'LevelAdvancedCountD12_rolling_5_mean',
#  'LevelAdvancedCountD13_rolling_5_mean',
#  'LevelAdvancedCountD14_rolling_5_mean',
#  'LevelAdvancedCountD15_rolling_5_mean',
#  'LevelAdvancedCountD1_rolling_5_max',
#  'LevelAdvancedCountD2_rolling_5_max',
#  'LevelAdvancedCountD3_rolling_5_max',
#  'LevelAdvancedCountD4_rolling_5_max',
#  'LevelAdvancedCountD5_rolling_5_max',
#  'LevelAdvancedCountD6_rolling_5_max',
#  'LevelAdvancedCountD7_rolling_5_max',
#  'LevelAdvancedCountD8_rolling_5_max',
#  'LevelAdvancedCountD9_rolling_5_max',
#  'LevelAdvancedCountD10_rolling_5_max',
#  'LevelAdvancedCountD11_rolling_5_max',
#  'LevelAdvancedCountD12_rolling_5_max',
#  'LevelAdvancedCountD13_rolling_5_max',
#  'LevelAdvancedCountD14_rolling_5_max',
#  'LevelAdvancedCountD15_rolling_5_max',
#  'Level_1_Duration_cummax',
#  'Level_2_Duration_cummax',
#  'Level_3_Duration_cummax',
#  'Level_4_Duration_cummax',
#  'Level_5_Duration_cummax',
#  'Level_6_Duration_cummax',
#  'Level_7_Duration_cummax',
#  'Level_8_Duration_cummax',
#  'Level_9_Duration_cummax',
#  'Level_10_Duration_cummax',
#  'Level_1_Duration_cummin',
#  'Level_2_Duration_cummin',
#  'Level_3_Duration_cummin',
#  'Level_4_Duration_cummin',
#  'Level_5_Duration_cummin',
#  'Level_6_Duration_cummin',
#  'Level_7_Duration_cummin',
#  'Level_8_Duration_cummin',
#  'Level_9_Duration_cummin',
#  'Level_10_Duration_cummin',
#  'Level_1_Duration_cumsum',
#  'Level_2_Duration_cumsum',
#  'Level_3_Duration_cumsum',
#  'Level_4_Duration_cumsum',
#  'Level_5_Duration_cumsum',
#  'Level_6_Duration_cumsum',
#  'Level_7_Duration_cumsum',
#  'Level_8_Duration_cumsum',
#  'Level_9_Duration_cumsum',
#  'Level_10_Duration_cumsum',
#  'duration_sum',
#  'duration_std',
#  'Level_2_Duration_rolling_2_mean',
#  'Level_3_Duration_rolling_2_mean',
#  'Level_4_Duration_rolling_2_mean',
#  'Level_5_Duration_rolling_2_mean',
#  'Level_6_Duration_rolling_2_mean',
#  'Level_7_Duration_rolling_2_mean',
#  'Level_8_Duration_rolling_2_mean',
#  'Level_9_Duration_rolling_2_mean',
#  'Level_10_Duration_rolling_2_mean',
#  'Level_2_Duration_rolling_2_max',
#  'Level_3_Duration_rolling_2_max',
#  'Level_4_Duration_rolling_2_max',
#  'Level_5_Duration_rolling_2_max',
#  'Level_6_Duration_rolling_2_max',
#  'Level_7_Duration_rolling_2_max',
#  'Level_8_Duration_rolling_2_max',
#  'Level_9_Duration_rolling_2_max',
#  'Level_10_Duration_rolling_2_max',
#  'Level_2_Duration_rolling_3_mean',
#  'Level_3_Duration_rolling_3_mean',
#  'Level_4_Duration_rolling_3_mean',
#  'Level_5_Duration_rolling_3_mean',
#  'Level_6_Duration_rolling_3_mean',
#  'Level_7_Duration_rolling_3_mean',
#  'Level_8_Duration_rolling_3_mean',
#  'Level_9_Duration_rolling_3_mean',
#  'Level_10_Duration_rolling_3_mean',
#  'Level_2_Duration_rolling_3_max',
#  'Level_3_Duration_rolling_3_max',
#  'Level_4_Duration_rolling_3_max',
#  'Level_5_Duration_rolling_3_max',
#  'Level_6_Duration_rolling_3_max',
#  'Level_7_Duration_rolling_3_max',
#  'Level_8_Duration_rolling_3_max',
#  'Level_9_Duration_rolling_3_max',
#  'Level_10_Duration_rolling_3_max',
#  'Level_2_Duration_rolling_4_mean',
#  'Level_3_Duration_rolling_4_mean',
#  'Level_4_Duration_rolling_4_mean',
#  'Level_5_Duration_rolling_4_mean',
#  'Level_6_Duration_rolling_4_mean',
#  'Level_7_Duration_rolling_4_mean',
#  'Level_8_Duration_rolling_4_mean',
#  'Level_9_Duration_rolling_4_mean',
#  'Level_10_Duration_rolling_4_mean',
#  'Level_2_Duration_rolling_4_max',
#  'Level_3_Duration_rolling_4_max',
#  'Level_4_Duration_rolling_4_max',
#  'Level_5_Duration_rolling_4_max',
#  'Level_6_Duration_rolling_4_max',
#  'Level_7_Duration_rolling_4_max',
#  'Level_8_Duration_rolling_4_max',
#  'Level_9_Duration_rolling_4_max',
#  'Level_10_Duration_rolling_4_max',
#  'Level_2_Duration_rolling_5_mean',
#  'Level_3_Duration_rolling_5_mean',
#  'Level_4_Duration_rolling_5_mean',
#  'Level_5_Duration_rolling_5_mean',
#  'Level_6_Duration_rolling_5_mean',
#  'Level_7_Duration_rolling_5_mean',
#  'Level_8_Duration_rolling_5_mean',
#  'Level_9_Duration_rolling_5_mean',
#  'Level_10_Duration_rolling_5_mean',
#  'Level_2_Duration_rolling_5_max',
#  'Level_3_Duration_rolling_5_max',
#  'Level_4_Duration_rolling_5_max',
#  'Level_5_Duration_rolling_5_max',
#  'Level_6_Duration_rolling_5_max',
#  'Level_7_Duration_rolling_5_max',
#  'Level_8_Duration_rolling_5_max',
#  'Level_9_Duration_rolling_5_max',
#  'Level_10_Duration_rolling_5_max',
#  'AdRevenueD0_cummax',
#  'AdRevenueD1_cummax',
#  'AdRevenueD2_cummax',
#  'AdRevenueD3_cummax',
#  'AdRevenueD4_cummax',
#  'AdRevenueD5_cummax',
#  'AdRevenueD6_cummax',
#  'AdRevenueD7_cummax',
#  'AdRevenueD8_cummax',
#  'AdRevenueD9_cummax',
#  'AdRevenueD10_cummax',
#  'AdRevenueD11_cummax',
#  'AdRevenueD12_cummax',
#  'AdRevenueD13_cummax',
#  'AdRevenueD14_cummax',
#  'AdRevenueD15_cummax',
#  'AdRevenueD0_cummin',
#  'AdRevenueD1_cummin',
#  'AdRevenueD2_cummin',
#  'AdRevenueD3_cummin',
#  'AdRevenueD4_cummin',
#  'AdRevenueD5_cummin',
#  'AdRevenueD6_cummin',
#  'AdRevenueD7_cummin',
#  'AdRevenueD8_cummin',
#  'AdRevenueD9_cummin',
#  'AdRevenueD10_cummin',
#  'AdRevenueD11_cummin',
#  'AdRevenueD12_cummin',
#  'AdRevenueD13_cummin',
#  'AdRevenueD14_cummin',
#  'AdRevenueD15_cummin',
#  'AdRevenueD0_cumsum',
#  'AdRevenueD1_cumsum',
#  'AdRevenueD2_cumsum',
#  'AdRevenueD3_cumsum',
#  'AdRevenueD4_cumsum',
#  'AdRevenueD5_cumsum',
#  'AdRevenueD6_cumsum',
#  'AdRevenueD7_cumsum',
#  'AdRevenueD8_cumsum',
#  'AdRevenueD9_cumsum',
#  'AdRevenueD10_cumsum',
#  'AdRevenueD11_cumsum',
#  'AdRevenueD12_cumsum',
#  'AdRevenueD13_cumsum',
#  'AdRevenueD14_cumsum',
#  'AdRevenueD15_cumsum',
#  'ad_revenue_sum',
#  'ad_revenue_std',
#  'AdRevenueD1_rolling_2_mean',
#  'AdRevenueD2_rolling_2_mean',
#  'AdRevenueD3_rolling_2_mean',
#  'AdRevenueD4_rolling_2_mean',
#  'AdRevenueD5_rolling_2_mean',
#  'AdRevenueD6_rolling_2_mean',
#  'AdRevenueD7_rolling_2_mean',
#  'AdRevenueD8_rolling_2_mean',
#  'AdRevenueD9_rolling_2_mean',
#  'AdRevenueD10_rolling_2_mean',
#  'AdRevenueD11_rolling_2_mean',
#  'AdRevenueD12_rolling_2_mean',
#  'AdRevenueD13_rolling_2_mean',
#  'AdRevenueD14_rolling_2_mean',
#  'AdRevenueD15_rolling_2_mean',
#  'AdRevenueD1_rolling_2_max',
#  'AdRevenueD2_rolling_2_max',
#  'AdRevenueD3_rolling_2_max',
#  'AdRevenueD4_rolling_2_max',
#  'AdRevenueD5_rolling_2_max',
#  'AdRevenueD6_rolling_2_max',
#  'AdRevenueD7_rolling_2_max',
#  'AdRevenueD8_rolling_2_max',
#  'AdRevenueD9_rolling_2_max',
#  'AdRevenueD10_rolling_2_max',
#  'AdRevenueD11_rolling_2_max',
#  'AdRevenueD12_rolling_2_max',
#  'AdRevenueD13_rolling_2_max',
#  'AdRevenueD14_rolling_2_max',
#  'AdRevenueD15_rolling_2_max',
#  'AdRevenueD1_rolling_3_mean',
#  'AdRevenueD2_rolling_3_mean',
#  'AdRevenueD3_rolling_3_mean',
#  'AdRevenueD4_rolling_3_mean',
#  'AdRevenueD5_rolling_3_mean',
#  'AdRevenueD6_rolling_3_mean',
#  'AdRevenueD7_rolling_3_mean',
#  'AdRevenueD8_rolling_3_mean',
#  'AdRevenueD9_rolling_3_mean',
#  'AdRevenueD10_rolling_3_mean',
#  'AdRevenueD11_rolling_3_mean',
#  'AdRevenueD12_rolling_3_mean',
#  'AdRevenueD13_rolling_3_mean',
#  'AdRevenueD14_rolling_3_mean',
#  'AdRevenueD15_rolling_3_mean',
#  'AdRevenueD1_rolling_3_max',
#  'AdRevenueD2_rolling_3_max',
#  'AdRevenueD3_rolling_3_max',
#  'AdRevenueD4_rolling_3_max',
#  'AdRevenueD5_rolling_3_max',
#  'AdRevenueD6_rolling_3_max',
#  'AdRevenueD7_rolling_3_max',
#  'AdRevenueD8_rolling_3_max',
#  'AdRevenueD9_rolling_3_max',
#  'AdRevenueD10_rolling_3_max',
#  'AdRevenueD11_rolling_3_max',
#  'AdRevenueD12_rolling_3_max',
#  'AdRevenueD13_rolling_3_max',
#  'AdRevenueD14_rolling_3_max',
#  'AdRevenueD15_rolling_3_max',
#  'AdRevenueD1_rolling_4_mean',
#  'AdRevenueD2_rolling_4_mean',
#  'AdRevenueD3_rolling_4_mean',
#  'AdRevenueD4_rolling_4_mean',
#  'AdRevenueD5_rolling_4_mean',
#  'AdRevenueD6_rolling_4_mean',
#  'AdRevenueD7_rolling_4_mean',
#  'AdRevenueD8_rolling_4_mean',
#  'AdRevenueD9_rolling_4_mean',
#  'AdRevenueD10_rolling_4_mean',
#  'AdRevenueD11_rolling_4_mean',
#  'AdRevenueD12_rolling_4_mean',
#  'AdRevenueD13_rolling_4_mean',
#  'AdRevenueD14_rolling_4_mean',
#  'AdRevenueD15_rolling_4_mean',
#  'AdRevenueD1_rolling_4_max',
#  'AdRevenueD2_rolling_4_max',
#  'AdRevenueD3_rolling_4_max',
#  'AdRevenueD4_rolling_4_max',
#  'AdRevenueD5_rolling_4_max',
#  'AdRevenueD6_rolling_4_max',
#  'AdRevenueD7_rolling_4_max',
#  'AdRevenueD8_rolling_4_max',
#  'AdRevenueD9_rolling_4_max',
#  'AdRevenueD10_rolling_4_max',
#  'AdRevenueD11_rolling_4_max',
#  'AdRevenueD12_rolling_4_max',
#  'AdRevenueD13_rolling_4_max',
#  'AdRevenueD14_rolling_4_max',
#  'AdRevenueD15_rolling_4_max',
#  'AdRevenueD1_rolling_5_mean',
#  'AdRevenueD2_rolling_5_mean',
#  'AdRevenueD3_rolling_5_mean',
#  'AdRevenueD4_rolling_5_mean',
#  'AdRevenueD5_rolling_5_mean',
#  'AdRevenueD6_rolling_5_mean',
#  'AdRevenueD7_rolling_5_mean',
#  'AdRevenueD8_rolling_5_mean',
#  'AdRevenueD9_rolling_5_mean',
#  'AdRevenueD10_rolling_5_mean',
#  'AdRevenueD11_rolling_5_mean',
#  'AdRevenueD12_rolling_5_mean',
#  'AdRevenueD13_rolling_5_mean',
#  'AdRevenueD14_rolling_5_mean',
#  'AdRevenueD15_rolling_5_mean',
#  'AdRevenueD1_rolling_5_max',
#  'AdRevenueD2_rolling_5_max',
#  'AdRevenueD3_rolling_5_max',
#  'AdRevenueD4_rolling_5_max',
#  'AdRevenueD5_rolling_5_max',
#  'AdRevenueD6_rolling_5_max',
#  'AdRevenueD7_rolling_5_max',
#  'AdRevenueD8_rolling_5_max',
#  'AdRevenueD9_rolling_5_max',
#  'AdRevenueD10_rolling_5_max',
#  'AdRevenueD11_rolling_5_max',
#  'AdRevenueD12_rolling_5_max',
#  'AdRevenueD13_rolling_5_max',
#  'AdRevenueD14_rolling_5_max',
#  'AdRevenueD15_rolling_5_max',
#  'IAPRevenueD0_cummax',
#  'IAPRevenueD1_cummax',
#  'IAPRevenueD2_cummax',
#  'IAPRevenueD3_cummax',
#  'IAPRevenueD4_cummax',
#  'IAPRevenueD5_cummax',
#  'IAPRevenueD6_cummax',
#  'IAPRevenueD7_cummax',
#  'IAPRevenueD8_cummax',
#  'IAPRevenueD9_cummax',
#  'IAPRevenueD10_cummax',
#  'IAPRevenueD11_cummax',
#  'IAPRevenueD12_cummax',
#  'IAPRevenueD13_cummax',
#  'IAPRevenueD14_cummax',
#  'IAPRevenueD15_cummax',
#  'IAPRevenueD0_cummin',
#  'IAPRevenueD1_cummin',
#  'IAPRevenueD2_cummin',
#  'IAPRevenueD3_cummin',
#  'IAPRevenueD4_cummin',
#  'IAPRevenueD5_cummin',
#  'IAPRevenueD6_cummin',
#  'IAPRevenueD7_cummin',
#  'IAPRevenueD8_cummin',
#  'IAPRevenueD9_cummin',
#  'IAPRevenueD10_cummin',
#  'IAPRevenueD11_cummin',
#  'IAPRevenueD12_cummin',
#  'IAPRevenueD13_cummin',
#  'IAPRevenueD14_cummin',
#  'IAPRevenueD15_cummin',
#  'IAPRevenueD0_cumsum',
#  'IAPRevenueD1_cumsum',
#  'IAPRevenueD2_cumsum',
#  'IAPRevenueD3_cumsum',
#  'IAPRevenueD4_cumsum',
#  'IAPRevenueD5_cumsum',
#  'IAPRevenueD6_cumsum',
#  'IAPRevenueD7_cumsum',
#  'IAPRevenueD8_cumsum',
#  'IAPRevenueD9_cumsum',
#  'IAPRevenueD10_cumsum',
#  'IAPRevenueD11_cumsum',
#  'IAPRevenueD12_cumsum',
#  'IAPRevenueD13_cumsum',
#  'IAPRevenueD14_cumsum',
#  'IAPRevenueD15_cumsum',
#  'ap_revenue_sum',
#  'ap_revenue_std',
#  'IAPRevenueD1_rolling_2_mean',
#  'IAPRevenueD2_rolling_2_mean',
#  'IAPRevenueD3_rolling_2_mean',
#  'IAPRevenueD4_rolling_2_mean',
#  'IAPRevenueD5_rolling_2_mean',
#  'IAPRevenueD6_rolling_2_mean',
#  'IAPRevenueD7_rolling_2_mean',
#  'IAPRevenueD8_rolling_2_mean',
#  'IAPRevenueD9_rolling_2_mean',
#  'IAPRevenueD10_rolling_2_mean',
#  'IAPRevenueD11_rolling_2_mean',
#  'IAPRevenueD12_rolling_2_mean',
#  'IAPRevenueD13_rolling_2_mean',
#  'IAPRevenueD14_rolling_2_mean',
#  'IAPRevenueD15_rolling_2_mean',
#  'IAPRevenueD1_rolling_2_max',
#  'IAPRevenueD2_rolling_2_max',
#  'IAPRevenueD3_rolling_2_max',
#  'IAPRevenueD4_rolling_2_max',
#  'IAPRevenueD5_rolling_2_max',
#  'IAPRevenueD6_rolling_2_max',
#  'IAPRevenueD7_rolling_2_max',
#  'IAPRevenueD8_rolling_2_max',
#  'IAPRevenueD9_rolling_2_max',
#  'IAPRevenueD10_rolling_2_max',
#  'IAPRevenueD11_rolling_2_max',
#  'IAPRevenueD12_rolling_2_max',
#  'IAPRevenueD13_rolling_2_max',
#  'IAPRevenueD14_rolling_2_max',
#  'IAPRevenueD15_rolling_2_max',
#  'IAPRevenueD1_rolling_3_mean',
#  'IAPRevenueD2_rolling_3_mean',
#  'IAPRevenueD3_rolling_3_mean',
#  'IAPRevenueD4_rolling_3_mean',
#  'IAPRevenueD5_rolling_3_mean',
#  'IAPRevenueD6_rolling_3_mean',
#  'IAPRevenueD7_rolling_3_mean',
#  'IAPRevenueD8_rolling_3_mean',
#  'IAPRevenueD9_rolling_3_mean',
#  'IAPRevenueD10_rolling_3_mean',
#  'IAPRevenueD11_rolling_3_mean',
#  'IAPRevenueD12_rolling_3_mean',
#  'IAPRevenueD13_rolling_3_mean',
#  'IAPRevenueD14_rolling_3_mean',
#  'IAPRevenueD15_rolling_3_mean',
#  'IAPRevenueD1_rolling_3_max',
#  'IAPRevenueD2_rolling_3_max',
#  'IAPRevenueD3_rolling_3_max',
#  'IAPRevenueD4_rolling_3_max',
#  'IAPRevenueD5_rolling_3_max',
#  'IAPRevenueD6_rolling_3_max',
#  'IAPRevenueD7_rolling_3_max',
#  'IAPRevenueD8_rolling_3_max',
#  'IAPRevenueD9_rolling_3_max',
#  'IAPRevenueD10_rolling_3_max',
#  'IAPRevenueD11_rolling_3_max',
#  'IAPRevenueD12_rolling_3_max',
#  'IAPRevenueD13_rolling_3_max',
#  'IAPRevenueD14_rolling_3_max',
#  'IAPRevenueD15_rolling_3_max',
#  'IAPRevenueD1_rolling_4_mean',
#  'IAPRevenueD2_rolling_4_mean',
#  'IAPRevenueD3_rolling_4_mean',
#  'IAPRevenueD4_rolling_4_mean',
#  'IAPRevenueD5_rolling_4_mean',
#  'IAPRevenueD6_rolling_4_mean',
#  'IAPRevenueD7_rolling_4_mean',
#  'IAPRevenueD8_rolling_4_mean',
#  'IAPRevenueD9_rolling_4_mean',
#  'IAPRevenueD10_rolling_4_mean',
#  'IAPRevenueD11_rolling_4_mean',
#  'IAPRevenueD12_rolling_4_mean',
#  'IAPRevenueD13_rolling_4_mean',
#  'IAPRevenueD14_rolling_4_mean',
#  'IAPRevenueD15_rolling_4_mean',
#  'IAPRevenueD1_rolling_4_max',
#  'IAPRevenueD2_rolling_4_max',
#  'IAPRevenueD3_rolling_4_max',
#  'IAPRevenueD4_rolling_4_max',
#  'IAPRevenueD5_rolling_4_max',
#  'IAPRevenueD6_rolling_4_max',
#  'IAPRevenueD7_rolling_4_max',
#  'IAPRevenueD8_rolling_4_max',
#  'IAPRevenueD9_rolling_4_max',
#  'IAPRevenueD10_rolling_4_max',
#  'IAPRevenueD11_rolling_4_max',
#  'IAPRevenueD12_rolling_4_max',
#  'IAPRevenueD13_rolling_4_max',
#  'IAPRevenueD14_rolling_4_max',
#  'IAPRevenueD15_rolling_4_max',
#  'IAPRevenueD1_rolling_5_mean',
#  'IAPRevenueD2_rolling_5_mean',
#  'IAPRevenueD3_rolling_5_mean',
#  'IAPRevenueD4_rolling_5_mean',
#  'IAPRevenueD5_rolling_5_mean',
#  'IAPRevenueD6_rolling_5_mean',
#  'IAPRevenueD7_rolling_5_mean',
#  'IAPRevenueD8_rolling_5_mean',
#  'IAPRevenueD9_rolling_5_mean',
#  'IAPRevenueD10_rolling_5_mean',
#  'IAPRevenueD11_rolling_5_mean',
#  'IAPRevenueD12_rolling_5_mean',
#  'IAPRevenueD13_rolling_5_mean',
#  'IAPRevenueD14_rolling_5_mean',
#  'IAPRevenueD15_rolling_5_mean',
#  'IAPRevenueD1_rolling_5_max',
#  'IAPRevenueD2_rolling_5_max',
#  'IAPRevenueD3_rolling_5_max',
#  'IAPRevenueD4_rolling_5_max',
#  'IAPRevenueD5_rolling_5_max',
#  'IAPRevenueD6_rolling_5_max',
#  'IAPRevenueD7_rolling_5_max',
#  'IAPRevenueD8_rolling_5_max',
#  'IAPRevenueD9_rolling_5_max',
#  'IAPRevenueD10_rolling_5_max',
#  'IAPRevenueD11_rolling_5_max',
#  'IAPRevenueD12_rolling_5_max',
#  'IAPRevenueD13_rolling_5_max',
#  'IAPRevenueD14_rolling_5_max',
#  'IAPRevenueD15_rolling_5_max',
#  'RetentionD1_rolling_2_mean',
#  'RetentionD2_rolling_2_mean',
#  'RetentionD3_rolling_2_mean',
#  'RetentionD4_rolling_2_mean',
#  'RetentionD5_rolling_2_mean',
#  'RetentionD6_rolling_2_mean',
#  'RetentionD7_rolling_2_mean',
#  'RetentionD8_rolling_2_mean',
#  'RetentionD9_rolling_2_mean',
#  'RetentionD10_rolling_2_mean',
#  'RetentionD11_rolling_2_mean',
#  'RetentionD12_rolling_2_mean',
#  'RetentionD13_rolling_2_mean',
#  'RetentionD14_rolling_2_mean',
#  'RetentionD15_rolling_2_mean',
#  'RetentionD1_rolling_3_mean',
#  'RetentionD2_rolling_3_mean',
#  'RetentionD3_rolling_3_mean',
#  'RetentionD4_rolling_3_mean',
#  'RetentionD5_rolling_3_mean',
#  'RetentionD6_rolling_3_mean',
#  'RetentionD7_rolling_3_mean',
#  'RetentionD8_rolling_3_mean',
#  'RetentionD9_rolling_3_mean',
#  'RetentionD10_rolling_3_mean',
#  'RetentionD11_rolling_3_mean',
#  'RetentionD12_rolling_3_mean',
#  'RetentionD13_rolling_3_mean',
#  'RetentionD14_rolling_3_mean',
#  'RetentionD15_rolling_3_mean',
#  'RetentionD1_rolling_4_mean',
#  'RetentionD2_rolling_4_mean',
#  'RetentionD3_rolling_4_mean',
#  'RetentionD4_rolling_4_mean',
#  'RetentionD5_rolling_4_mean',
#  'RetentionD6_rolling_4_mean',
#  'RetentionD7_rolling_4_mean',
#  'RetentionD8_rolling_4_mean',
#  'RetentionD9_rolling_4_mean',
#  'RetentionD10_rolling_4_mean',
#  'RetentionD11_rolling_4_mean',
#  'RetentionD12_rolling_4_mean',
#  'RetentionD13_rolling_4_mean',
#  'RetentionD14_rolling_4_mean',
#  'RetentionD15_rolling_4_mean',
#  'RetentionD1_rolling_5_mean',
#  'RetentionD2_rolling_5_mean',
#  'RetentionD3_rolling_5_mean',
#  'RetentionD4_rolling_5_mean',
#  'RetentionD5_rolling_5_mean',
#  'RetentionD6_rolling_5_mean',
#  'RetentionD7_rolling_5_mean',
#  'RetentionD8_rolling_5_mean',
#  'RetentionD9_rolling_5_mean',
#  'RetentionD10_rolling_5_mean',
#  'RetentionD11_rolling_5_mean',
#  'RetentionD12_rolling_5_mean',
#  'RetentionD13_rolling_5_mean',
#  'RetentionD14_rolling_5_mean',
#  'RetentionD15_rolling_5_mean',
#  'LevelAdvancedCountD0_div_col',
#  'LevelAdvancedCountD1_div_col',
#  'LevelAdvancedCountD2_div_col',
#  'LevelAdvancedCountD3_div_col',
#  'LevelAdvancedCountD4_div_col',
#  'LevelAdvancedCountD5_div_col',
#  'LevelAdvancedCountD6_div_col',
#  'LevelAdvancedCountD7_div_col',
#  'LevelAdvancedCountD8_div_col',
#  'LevelAdvancedCountD9_div_col',
#  'LevelAdvancedCountD10_div_col',
#  'LevelAdvancedCountD11_div_col',
#  'LevelAdvancedCountD12_div_col',
#  'LevelAdvancedCountD13_div_col',
#  'LevelAdvancedCountD14_div_col',
#  'Level_1_Duration_div_col',
#  'Level_2_Duration_div_col',
#  'Level_3_Duration_div_col',
#  'Level_4_Duration_div_col',
#  'Level_5_Duration_div_col',
#  'Level_6_Duration_div_col',
#  'Level_7_Duration_div_col',
#  'Level_8_Duration_div_col',
#  'Level_9_Duration_div_col',
#  'AdRevenueD0_div_col',
#  'AdRevenueD1_div_col',
#  'AdRevenueD2_div_col',
#  'AdRevenueD3_div_col',
#  'AdRevenueD4_div_col',
#  'AdRevenueD5_div_col',
#  'AdRevenueD6_div_col',
#  'AdRevenueD7_div_col',
#  'AdRevenueD8_div_col',
#  'AdRevenueD9_div_col',
#  'AdRevenueD10_div_col',
#  'AdRevenueD11_div_col',
#  'AdRevenueD12_div_col',
#  'AdRevenueD13_div_col',
#  'AdRevenueD14_div_col',
#  'IAPRevenueD0_div_col',
#  'IAPRevenueD1_div_col',
#  'IAPRevenueD2_div_col',
#  'IAPRevenueD3_div_col',
#  'IAPRevenueD4_div_col',
#  'IAPRevenueD5_div_col',
#  'IAPRevenueD6_div_col',
#  'IAPRevenueD7_div_col',
#  'IAPRevenueD8_div_col',
#  'IAPRevenueD9_div_col',
#  'IAPRevenueD10_div_col',
#  'IAPRevenueD11_div_col',
#  'IAPRevenueD12_div_col',
#  'IAPRevenueD13_div_col',
#  'IAPRevenueD14_div_col',
#  'advanced_zero_count',
#  'advanced_nonzero_count',
#  'duration_zero_count',
#  'duration_nonzero_count',
#  'ad_revenue_zero_count',
#  'ad_revenue_nonzero_count',
#  'ap_revenue_zero_count',
#  'ap_revenue_nonzero_count']

# %% [markdown]
# ## submission

# %%
sub_df = pd.DataFrame(merged_test[["ID"]].iloc[:,0])

# %%
sad = {"selected_cols":train_cols, "train_df":merged_train, "test_df":merged_test, "cat_features": cat_cols, "iterations":5, "learning_rate":0.05,
       "use_mean_encoding":True,"task_type":"GPU"}


def get_submissions(selected_cols, train_df, test_df, use_mean_encoding,cat_features, iterations, learning_rate, task_type):

    X_train = train_df[selected_cols] 
    X_test = test_df[selected_cols] 
    y_train = train_df["target"].values

    submission_model=CatBoostRegressor(cat_features=cat_features, iterations=iterations, learning_rate = learning_rate, task_type=task_type)

    if use_mean_encoding:
        X_train, X_test = get_cat_mean_feature(train_df[selected_cols  + ["target"]] ,
            test_df[selected_cols])
    
    submission_model.fit(X_train, y_train)
    y_pred_sub = submission_model.predict(X_test)
    y_pred_train_sub = submission_model.predict(X_train)

    train_score = get_score(y_train, y_pred_train_sub)
    

    df = sub_df.copy()
    df["TARGET"] = y_pred_sub
    df.to_csv(f"{iterations}_{learning_rate}_{use_mean_encoding}_fugo.csv")

    return y_pred_sub, y_pred_train_sub, train_score

for iterations in [500, 50,100,1000]:
    for learning_rate in [0.1, 0.5, 0.05]:
        for use_mean_encoding in [True, False]:
            sad = {"selected_cols":train_cols, "train_df":merged_train, "test_df":merged_test, "cat_features": cat_cols, "iterations":iterations, "learning_rate":learning_rate,
                    "use_mean_encoding":use_mean_encoding,"task_type":"GPU"}
            y_pred_sub, y_pred_train_sub, train_score = get_submissions(**sad)

            break

# %%
merged_train[cat_cols].iloc[:2000]
# Out:
#                country platform device_category device_brand  \
# 0               Mexico  Android          mobile       Xiaomi
# 1                 Peru  Android          mobile      Samsung
# 2               Brazil  Android          mobile       Xiaomi
# 3   Dominican Republic      iOS          mobile        Apple
# 4              Ecuador  Android          mobile     Motorola
# ..                 ...      ...             ...          ...
# 95              Sweden      iOS          mobile        Apple
# 96       United States      iOS          mobile        Apple
# 97             Romania  Android          mobile      Samsung
# 98       United States  Android          mobile      Samsung
# 99           Indonesia  Android          mobile         OPPO
#
#          device_model    ad_network
# 0            Redmi A2  unityads_int
# 1          Galaxy A13  applovin_int
# 2            Redmi 12  applovin_int
# 3   iPhone 11 Pro Max           nan
# 4            Moto E22  applovin_int
# ..                ...           ...
# 95  iPhone 13 Pro Max           nan
# 96          iPhone 11  applovin_int
# 97         Galaxy S22           nan
# 98   Galaxy S22 Ultra  applovin_int
# 99             A78 4G  applovin_int
#
# [100 rows x 6 columns]

# %%
merged_train[cat_cols].iloc[:2000].device_model.unique()
# Out:
# array(['Redmi A2', 'Galaxy A13', 'Redmi 12', 'iPhone 11 Pro Max',
#        'Moto E22', 'Redmi Note 8', 'Galaxy S20 FE', 'iPhone 11', 'X9b',
#        'iPhone SE (2nd generation)', 'Galaxy S23', 'iPhone 14 Pro Max',
#        'Moto E13', 'Redmi Note 10S', 'Redmi 12 5G', 'Moto E32',
#        'Galaxy Z Flip 5', 'iPhone 13 Pro', 'Moto G84 5G', 'Galaxy Tab S8',
#        'iPhone 13', 'Honor 9X(China)', 'iPhone 13 Pro Max', 'Y73',
#        'iPad (9th gen)', 'iPhone 14', 'BISON Pro', 'Moto e20', 'A77s',
#        'Galaxy S22 Ultra', 'moto g53 5G', 'iPhone', 'iPhone XS Max',
#        'C35', 'X8A', 'moto g(60)s', 'Galaxy S24+', 'Axon 50 Lite',
#        'Galaxy A04', 'iPhone 8', 'iPad Air (4th gen)', 'iPhone 12 mini',
#        'Galaxy A03 Core', 'Redmi Note 12 Pro 4G', 'Galaxy A14 5G',
#        'Galaxy A32 5G', 'moto g23', 'X7a', 'Redmi Note 12 4G',
#        'Galaxy A71 5G', 'iPhone XR', 'Galaxy A14', 'Galaxy S24 Ultra',
#        'Moto G32', 'Redmi Note 5 Pro', 'iPhone 12', 'iPad Pro (11-inch)',
#        'Edge 30 Neo', 'Redmi 10C', 'Hot 30i', 'Galaxy J4+', 'Moto G52',
#        'Pixel 7', 'K61', 'Hot 30 Play NFC', 'Y52', 'Galaxy A12',
#        'Galaxy On6', 'Redmi 9i', 'iPad mini (5th generation)',
#        'Galaxy S22', 'A78 4G'], dtype=object)

# %%
path
# Out:
# 'C:/Users/HP/Desktop/fugo/'

# %%
def ff(i):
    general_path = "C:/Users/HP/Desktop/fugo/ind/" + i
    aa = pd.read_csv(general_path)
    print("sadsad")
    aa.drop("Unnamed: 0",axis=1).set_index("ID").to_csv("C:/Users/HP/Desktop/fugo/new/"+ f"{i}")

# %%
for i in os.listdir("C:/Users/HP/Desktop/fugo/ind/"):
    if "5000" in i:
        print(i)
        ff(i)
# Out:
# _new_trial_v2_5000_0.05_False_fugo.csv
# sadsad
# _new_trial_v2_5000_0.05_True_fugo.csv
# sadsad
# _new_trial_v2_5000_0.5_True_fugo.csv
# sadsad

# %%
# !kaggle competitions submit -c dacfugo -f C:/Users/HP/Desktop/fugo/new/_new_trial_v2_5000_0.5_True_fugo.csv -m "sub2"
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.12)
# Successfully submitted to DAC - Fugo Case
#   0%|          | 0.00/15.5M [00:00<?, ?B/s]
#   1%|          | 112k/15.5M [00:00<00:15, 1.02MB/s]
#   4%|▍         | 624k/15.5M [00:00<00:05, 3.04MB/s]
#   6%|▌         | 928k/15.5M [00:00<00:05, 3.00MB/s]
#  11%|█         | 1.66M/15.5M [00:00<00:03, 4.49MB/s]
#  13%|█▎        | 2.08M/15.5M [00:00<00:05, 2.43MB/s]
#  15%|█▌        | 2.41M/15.5M [00:01<00:07, 1.79MB/s]
#  19%|█▊        | 2.91M/15.5M [00:01<00:05, 2.34MB/s]
#  23%|██▎       | 3.61M/15.5M [00:01<00:03, 3.25MB/s]
#  27%|██▋       | 4.12M/15.5M [00:01<00:03, 3.65MB/s]
#  29%|██▉       | 4.58M/15.5M [00:01<00:03, 3.54MB/s]
#  32%|███▏      | 4.98M/15.5M [00:01<00:03, 3.10MB/s]
#  34%|███▍      | 5.34M/15.5M [00:01<00:03, 2.76MB/s]
#  39%|███▉      | 6.09M/15.5M [00:02<00:02, 3.78MB/s]
#  42%|████▏     | 6.53M/15.5M [00:02<00:02, 3.64MB/s]
#  45%|████▍     | 6.94M/15.5M [00:02<00:02, 3.63MB/s]
#  47%|████▋     | 7.33M/15.5M [00:02<00:02, 3.41MB/s]
#  50%|████▉     | 7.69M/15.5M [00:02<00:02, 3.43MB/s]
#  52%|█████▏    | 8.05M/15.5M [00:02<00:02, 3.48MB/s]
#  55%|█████▌    | 8.61M/15.5M [00:02<00:01, 4.02MB/s]
#  58%|█████▊    | 9.02M/15.5M [00:02<00:01, 4.07MB/s]
#  61%|██████    | 9.45M/15.5M [00:02<00:01, 4.21MB/s]
#  65%|██████▍   | 10.0M/15.5M [00:03<00:01, 4.60MB/s]
#  67%|██████▋   | 10.5M/15.5M [00:03<00:01, 4.27MB/s]
#  72%|███████▏  | 11.1M/15.5M [00:03<00:00, 5.01MB/s]
#  75%|███████▍  | 11.6M/15.5M [00:03<00:00, 4.87MB/s]
#  78%|███████▊  | 12.1M/15.5M [00:03<00:00, 4.74MB/s]
#  81%|████████  | 12.6M/15.5M [00:03<00:00, 4.83MB/s]
#  84%|████████▍ | 13.1M/15.5M [00:03<00:00, 4.56MB/s]
#  88%|████████▊ | 13.7M/15.5M [00:03<00:00, 4.91MB/s]
#  93%|█████████▎| 14.4M/15.5M [00:04<00:00, 5.55MB/s]
#  96%|█████████▋| 15.0M/15.5M [00:04<00:00, 4.70MB/s]
# 100%|█████████▉| 15.5M/15.5M [00:04<00:00, 4.68MB/s]
# 100%|██████████| 15.5M/15.5M [00:04<00:00, 3.46MB/s]

# %%
i
# Out:
# '100_0.05_True_fugo.csv'

# %%
for i in os.listdir("C:/Users/HP/Desktop/fugo/new/"):
    # !kaggle competitions submit -c dacfugo -f C:/Users/HP/Desktop/fugo/new/i -m "subbb"
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python311\Scripts\kaggle.exe\__main__.py", line 7, in <module>
#   File "c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\cli.py", line 54, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\api\kaggle_api_extended.py", line 806, in competition_submit_cli
#     submit_result = self.competition_submit(file_name, message,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\api\kaggle_api_extended.py", line 757, in competition_submit
#     content_length=os.path.getsize(file_name),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen genericpath>", line 50, in getsize
# FileNotFoundError: [WinError 2] Sistem belirtilen dosyayı bulamıyor: 'C:/Users/HP/Desktop/fugo/new/i'

# %%
def get_submission_df(selected_cols):
    df = sub_df.copy()
    y_pred_sub, _, _ = get_submissions(selected_cols, merged_train, merged_test)

    df["TARGET"] = y_pred_sub
    # df.to_csv("")
    return df

# %%
get_submission_df( "advanced")

# %%
train_cols
# Out:
# [['LevelAdvancedCountD0',
#   'LevelAdvancedCountD1',
#   'LevelAdvancedCountD2',
#   'LevelAdvancedCountD3',
#   'LevelAdvancedCountD4',
#   'LevelAdvancedCountD5',
#   'LevelAdvancedCountD6',
#   'LevelAdvancedCountD7',
#   'LevelAdvancedCountD8',
#   'LevelAdvancedCountD9',
#   'LevelAdvancedCountD10',
#   'LevelAdvancedCountD11',
#   'LevelAdvancedCountD12',
#   'LevelAdvancedCountD13',
#   'LevelAdvancedCountD14',
#   'LevelAdvancedCountD15']]

# %%
"LevelAdvancedCountD1" in merged_test.columns
# Out:
# True

# %%
# !kaggle competitions submit -c h-and-m-personalized-fashion-recommendations  -f ../input/h-and-m-personalized-fashion-recommendations/sample_submission.csv -m "Submission via API"

# %%
import os
os.environ["KAGGLE_USERNAME"]="ademsara"
os.environ["KAGGLE_KEY"]="yourapikey"

# %%
for 

# !kaggle competitions submit -c dacfugo -f C:/Users/HP/Desktop/fugo/new/500_0.1_True_fugo.csv -m "sub1"
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.12)
# Successfully submitted to DAC - Fugo Case
#   0%|          | 0.00/19.4M [00:00<?, ?B/s]
#   1%|          | 112k/19.4M [00:00<00:20, 1.01MB/s]
#   3%|▎         | 496k/19.4M [00:00<00:07, 2.63MB/s]
#   6%|▌         | 1.08M/19.4M [00:00<00:04, 4.09MB/s]
#   9%|▊         | 1.67M/19.4M [00:00<00:03, 4.86MB/s]
#  11%|█         | 2.14M/19.4M [00:00<00:06, 2.90MB/s]
#  13%|█▎        | 2.50M/19.4M [00:00<00:07, 2.27MB/s]
#  14%|█▍        | 2.80M/19.4M [00:01<00:07, 2.38MB/s]
#  16%|█▋        | 3.16M/19.4M [00:01<00:06, 2.68MB/s]
#  20%|█▉        | 3.81M/19.4M [00:01<00:04, 3.62MB/s]
#  22%|██▏       | 4.34M/19.4M [00:01<00:03, 4.04MB/s]
#  25%|██▌       | 4.86M/19.4M [00:01<00:03, 4.38MB/s]
#  28%|██▊       | 5.36M/19.4M [00:01<00:03, 4.48MB/s]
#  31%|███       | 6.02M/19.4M [00:01<00:02, 4.88MB/s]
#  34%|███▍      | 6.56M/19.4M [00:01<00:02, 5.09MB/s]
#  37%|███▋      | 7.08M/19.4M [00:01<00:02, 5.17MB/s]
#  40%|███▉      | 7.67M/19.4M [00:02<00:02, 5.29MB/s]
#  43%|████▎     | 8.38M/19.4M [00:02<00:02, 5.58MB/s]
#  46%|████▋     | 8.98M/19.4M [00:02<00:01, 5.77MB/s]
#  49%|████▉     | 9.58M/19.4M [00:02<00:01, 5.85MB/s]
#  52%|█████▏    | 10.1M/19.4M [00:02<00:02, 4.70MB/s]
#  57%|█████▋    | 11.1M/19.4M [00:02<00:01, 4.74MB/s]
#  60%|██████    | 11.7M/19.4M [00:02<00:01, 4.81MB/s]
#  63%|██████▎   | 12.2M/19.4M [00:02<00:01, 4.89MB/s]
#  66%|██████▌   | 12.7M/19.4M [00:03<00:01, 5.06MB/s]
#  69%|██████▊   | 13.3M/19.4M [00:03<00:01, 5.40MB/s]
#  71%|███████▏  | 13.8M/19.4M [00:03<00:01, 5.10MB/s]
#  78%|███████▊  | 15.1M/19.4M [00:03<00:00, 7.16MB/s]
#  82%|████████▏ | 15.8M/19.4M [00:03<00:00, 5.57MB/s]
#  85%|████████▍ | 16.4M/19.4M [00:03<00:00, 5.72MB/s]
#  89%|████████▊ | 17.2M/19.4M [00:03<00:00, 5.71MB/s]
#  92%|█████████▏| 17.8M/19.4M [00:03<00:00, 5.83MB/s]
#  95%|█████████▌| 18.4M/19.4M [00:04<00:00, 5.77MB/s]
#  98%|█████████▊| 19.0M/19.4M [00:04<00:00, 5.79MB/s]
# 100%|██████████| 19.4M/19.4M [00:04<00:00, 4.32MB/s]
